# %%
import numpy as np

# %%
draws = np.random.normal(size=1000)

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(draws, density=True);

# %%
def normal_pdf(x, mean=0, std=1):
    return 1/np.sqrt(2*np.pi*std**2) * np.exp(-(x - mean)**2/(2*std**2))

# %%
xs = np.linspace(-5,5, 100)

# %%
plt.hist(draws, density=True)
plt.plot(xs, normal_pdf(xs))

# %%
from scipy.stats.distributions import norm

# %%
norm.rvs(xs)
# Out:
# array([-5.225697  , -4.92357581, -5.09802735, -6.81617244, -6.49829988,
#        -2.34191663, -4.19259004, -3.78386229, -4.37124366, -4.57219583,
#        -4.50596533, -4.83294618, -3.80803982, -4.08522866, -2.20080157,
#        -2.36336571, -3.33130003, -4.48049432, -6.02683775, -3.79485486,
#        -3.42478305, -1.47325738, -2.9995665 , -1.55004363, -2.68526404,
#        -1.88962878, -2.95868284, -1.57170271, -2.91686496, -2.83105545,
#        -1.86424713, -2.14543012, -3.31336585, -1.96933239, -1.56577414,
#         1.75625088, -2.05951924, -1.95594802,  0.16539442,  0.14409456,
#        -0.44313383, -2.03441754, -0.76508671, -2.44784074, -3.08457022,
#        -0.70258366,  0.77095273, -0.41415977, -1.88709435,  0.77736554,
#         0.39275897,  0.60589756,  0.21134626,  0.61093878,  0.23648751,
#         0.29601661,  0.28991127,  0.9302349 ,  0.39001368, -0.07806801,
#         0.98264791,  1.0041763 ,  1.35287705,  2.31394524,  2.64670461,
#         3.27703692,  2.02912867,  0.58046539,  1.87701684,  2.09713251,
#         2.55179751,  3.19198431,  1.43692433,  2.21796769,  3.90512434,
#         0.85172157,  1.4363813 ,  3.6487714 ,  2.52475541,  2.68358544,
#         3.11000288,  3.38006362,  3.79829884,  3.48370821,  4.19591565,
#         1.89536426,  3.57953221,  2.41962528,  1.46958247,  4.22144083,
#         6.63781597,  4.13028373,  3.36364488,  6.20065554,  4.0553892 ,
#         5.3195063 ,  6.17862449,  3.99943735,  3.73037731,  5.38813862])
